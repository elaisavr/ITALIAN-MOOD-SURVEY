# %% [markdown]
# # Merge additional information to main Survey Dataframe

# %% [markdown]
# In this fourth notebook all details generated in notebook n.03 are merged into the main Survey Dataframe

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# read survey CSV
survey = pd.read_csv(r'data_clean/03_survey_to_merge.csv')
survey.head(3)
# Out:
#      User ID     Variable                                           Question  \
# 0  221250719  B11_Q62_A_1  Please find below some words indicating differ...
# 1   89508748  B11_Q62_A_1  Please find below some words indicating differ...
# 2   98143773  B11_Q62_A_1  Please find below some words indicating differ...
#
#              Topic                  Answer Label  Answer Value  Age    CAP  \
# 0  Active/ Dynamic                         A lot             5   20  70032
# 1  Active/ Dynamic  A little yes and a little no             3   21  87060
# 2  Active/ Dynamic                      A little             2   21  63822
#
#   City  Num. of Citizens  ... Num. of Children (0-14 years)  Season     Month  \
# 0   BA           56929.0  ...                             0  Winter  February
# 1   CS            1281.0  ...                             0  Winter  February
# 2   FM           16062.0  ...                             0  Winter  February
#
#   Time Slot  birth_year  Survey filling date Survey filling hour  Weekday  \
# 0   Evening        2003           14/02/2023            19:06:44  Tuesday
# 1   Evening        2002           27/02/2023            18:36:02   Monday
# 2   Evening        2002           19/02/2023            18:39:59   Sunday
#
#          Mood relationship General Mood
# 0  PANAS and Personal Life         Good
# 1  PANAS and Personal Life         Good
# 2  PANAS and Personal Life         Good
#
# [3 rows x 27 columns]

# %%
# read generation mapping, events and geographical details CSV
generation_mapping = pd.read_csv(r'data_update/generation_mapping.csv')
events = pd.read_csv(r'data_update/events.csv')
geo_details = pd.read_csv(r'data_update/geographical_details.csv')

# %%
generation_mapping.columns
# Out:
# Index(['Year', 'Generation', 'Generation Description'], dtype='object')

# %%
# merge survey with generation mapping containing cultural generations infos
survey = pd.merge(survey, generation_mapping, how='left', left_on='birth_year', right_on='Year')

# %%
print(survey.shape)
survey.head(3)
# Out:
# (641480, 30)
#      User ID     Variable                                           Question  \
# 0  221250719  B11_Q62_A_1  Please find below some words indicating differ...
# 1   89508748  B11_Q62_A_1  Please find below some words indicating differ...
# 2   98143773  B11_Q62_A_1  Please find below some words indicating differ...
#
#              Topic                  Answer Label  Answer Value  Age    CAP  \
# 0  Active/ Dynamic                         A lot             5   20  70032
# 1  Active/ Dynamic  A little yes and a little no             3   21  87060
# 2  Active/ Dynamic                      A little             2   21  63822
#
#   City  Num. of Citizens  ... Time Slot birth_year  Survey filling date  \
# 0   BA           56929.0  ...   Evening       2003           14/02/2023
# 1   CS            1281.0  ...   Evening       2002           27/02/2023
# 2   FM           16062.0  ...   Evening       2002           19/02/2023
#
#   Survey filling hour  Weekday        Mood relationship General Mood  Year  \
# 0            19:06:44  Tuesday  PANAS and Personal Life         Good  2003
# 1            18:36:02   Monday  PANAS and Personal Life         Good  2002
# 2            18:39:59   Sunday  PANAS and Personal Life         Good  2002
#
#                  Generation                             Generation Description
# 0  Generation Z 1997 - 2012  Generation Z (or Gen Z for short and colloquia...
# 1  Generation Z 1997 - 2012  Generation Z (or Gen Z for short and colloquia...
# 2  Generation Z 1997 - 2012  Generation Z (or Gen Z for short and colloquia...
#
# [3 rows x 30 columns]

# %%
events.columns
# Out:
# Index(['Events', 'Event month'], dtype='object')

# %%
# merge survey with events infos
survey = pd.merge(survey, events, how='left', left_on='Month', right_on='Event month')
print(survey.shape)
survey.head(3)
# Out:
# (641480, 32)
#      User ID     Variable                                           Question  \
# 0  221250719  B11_Q62_A_1  Please find below some words indicating differ...
# 1   89508748  B11_Q62_A_1  Please find below some words indicating differ...
# 2   98143773  B11_Q62_A_1  Please find below some words indicating differ...
#
#              Topic                  Answer Label  Answer Value  Age    CAP  \
# 0  Active/ Dynamic                         A lot             5   20  70032
# 1  Active/ Dynamic  A little yes and a little no             3   21  87060
# 2  Active/ Dynamic                      A little             2   21  63822
#
#   City  Num. of Citizens  ... Survey filling date Survey filling hour  \
# 0   BA           56929.0  ...          14/02/2023            19:06:44
# 1   CS            1281.0  ...          27/02/2023            18:36:02
# 2   FM           16062.0  ...          19/02/2023            18:39:59
#
#    Weekday        Mood relationship  General Mood  Year  \
# 0  Tuesday  PANAS and Personal Life          Good  2003
# 1   Monday  PANAS and Personal Life          Good  2002
# 2   Sunday  PANAS and Personal Life          Good  2002
#
#                  Generation  \
# 0  Generation Z 1997 - 2012
# 1  Generation Z 1997 - 2012
# 2  Generation Z 1997 - 2012
#
#                               Generation Description  \
# 0  Generation Z (or Gen Z for short and colloquia...
# 1  Generation Z (or Gen Z for short and colloquia...
# 2  Generation Z (or Gen Z for short and colloquia...
#
#                                               Events Event month
# 0  1 February – Lebanese liquidity crisis: The ce...    February
# 1  1 February – Lebanese liquidity crisis: The ce...    February
# 2  1 February – Lebanese liquidity crisis: The ce...    February
#
# [3 rows x 32 columns]

# %%
# check the column to merge of the main dataframe vs the geographical dataframe
print(survey['CAP'].info())
print(geo_details['City CAP'].info())
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 641480 entries, 0 to 641479
# Series name: CAP
# Non-Null Count   Dtype
# --------------   -----
# 641480 non-null  int64
# dtypes: int64(1)
# memory usage: 9.8 MB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 8463 entries, 0 to 8462
# Series name: City CAP
# Non-Null Count  Dtype
# --------------  -----
# 8463 non-null   int64
# dtypes: int64(1)
# memory usage: 66.2 KB
# None

# %%
# change dtype to match the following merge
geo_details['City CAP'] = [int(i) for i in geo_details['City CAP']]

# %%
survey.columns
# Out:
# Index(['User ID', 'Variable', 'Question', 'Topic', 'Answer Label',
#        'Answer Value', 'Age', 'CAP', 'City', 'Num. of Citizens',
#        'Highest Education', 'Survey filling date and time',
#        'Seconds to Answer', 'Sex', 'User Social Weight', 'idRispondente',
#        'Pet Friends', 'Num. of Children (0-14 years)', 'Season', 'Month',
#        'Time Slot', 'birth_year', 'Survey filling date', 'Survey filling hour',
#        'Weekday', 'Mood relationship', 'General Mood', 'Year', 'Generation',
#        'Generation Description', 'Events', 'Event month'],
#       dtype='object')

# %%
# merge main dataframe with the geographical details dataframe and drop duplicated values generated from the merge
survey = survey.merge(geo_details, how='left', left_on='CAP', right_on='City CAP')
print(survey.shape)
# Out:
# (1711298, 43)

# %%
# drop duplicated rows generated from merge
survey.drop_duplicates(subset=['User ID', 'Question', 'Topic', 'Answer Label'], keep='first', inplace=True, ignore_index=True)
print(survey.shape)
survey.isnull().sum()
# Out:
# (641480, 43)
# User ID                              0
# Variable                             0
# Question                             0
# Topic                            16240
# Answer Label                         0
# Answer Value                         0
# Age                                  0
# CAP                                  0
# City                             36814
# Num. of Citizens                  4582
# Highest Education                    0
# Survey filling date and time         0
# Seconds to Answer                 6873
# Sex                                  0
# User Social Weight                   0
# idRispondente                    49928
# Pet Friends                      49928
# Num. of Children (0-14 years)    49928
# Season                               0
# Month                                0
# Time Slot                            0
# birth_year                           0
# Survey filling date                  0
# Survey filling hour                  0
# Weekday                              0
# Mood relationship                    0
# General Mood                         0
# Year                                 0
# Generation                           0
# Generation Description               0
# Events                               0
# Event month                          0
# Municipality                     19276
# City CAP                         19276
# sigla_provincia                  52614
# City Name                        19276
# Region                           19276
# Region Type                      19276
# Latitude                         19276
# Longitude                        19276
# Altitude Profile                 19276
# Geo Position                     19276
# Urbanization Level               19276
# dtype: int64

# %%
# filter the remaining null values still resulting from the previous merge and assign it to a new dataframe 'null_position'
null_position = survey[survey['Geo Position'].isnull() == True]
print(null_position.shape)
null_position.head()
# Out:
# (19276, 43)
#         User ID     Variable  \
# 14   1906221911  B11_Q62_A_1
# 49   3003851093  B11_Q62_A_1
# 50   3984968717  B11_Q62_A_1
# 180  1236676492  B11_Q62_A_1
# 229  3851484828  B11_Q62_A_1
#
#                                               Question            Topic  \
# 14   Please find below some words indicating differ...  Active/ Dynamic
# 49   Please find below some words indicating differ...  Active/ Dynamic
# 50   Please find below some words indicating differ...  Active/ Dynamic
# 180  Please find below some words indicating differ...  Active/ Dynamic
# 229  Please find below some words indicating differ...  Active/ Dynamic
#
#                      Answer Label  Answer Value  Age    CAP City  \
# 14   A little yes and a little no             3   23  20165  NaN
# 49                    Quite a lot             4   26    100   RM
# 50   A little yes and a little no             3   26    100   RM
# 180  A little yes and a little no             3   31  10102  NaN
# 229  A little yes and a little no             3   32  10107  NaN
#
#      Num. of Citizens  ... City CAP sigla_provincia  City Name Region  \
# 14                NaN  ...      NaN             NaN        NaN    NaN
# 49          2546804.0  ...      NaN             NaN        NaN    NaN
# 50          2546804.0  ...      NaN             NaN        NaN    NaN
# 180               NaN  ...      NaN             NaN        NaN    NaN
# 229               NaN  ...      NaN             NaN        NaN    NaN
#
#      Region Type  Latitude Longitude Altitude Profile Geo Position  \
# 14           NaN       NaN       NaN              NaN          NaN
# 49           NaN       NaN       NaN              NaN          NaN
# 50           NaN       NaN       NaN              NaN          NaN
# 180          NaN       NaN       NaN              NaN          NaN
# 229          NaN       NaN       NaN              NaN          NaN
#
#     Urbanization Level
# 14                 NaN
# 49                 NaN
# 50                 NaN
# 180                NaN
# 229                NaN
#
# [5 rows x 43 columns]

# %%
pd.Series(null_position.columns)
# Out:
# 0                           User ID
# 1                          Variable
# 2                          Question
# 3                             Topic
# 4                      Answer Label
# 5                      Answer Value
# 6                               Age
# 7                               CAP
# 8                              City
# 9                  Num. of Citizens
# 10                Highest Education
# 11     Survey filling date and time
# 12                Seconds to Answer
# 13                              Sex
# 14               User Social Weight
# 15                    idRispondente
# 16                      Pet Friends
# 17    Num. of Children (0-14 years)
# 18                           Season
# 19                            Month
# 20                        Time Slot
# 21                       birth_year
# 22              Survey filling date
# 23              Survey filling hour
# 24                          Weekday
# 25                Mood relationship
# 26                     General Mood
# 27                             Year
# 28                       Generation
# 29           Generation Description
# 30                           Events
# 31                      Event month
# 32                     Municipality
# 33                         City CAP
# 34                  sigla_provincia
# 35                        City Name
# 36                           Region
# 37                      Region Type
# 38                         Latitude
# 39                        Longitude
# 40                 Altitude Profile
# 41                     Geo Position
# 42               Urbanization Level
# dtype: object

# %%
# drop the columns of the new 'null_position' dataframe in order to merge again the geographical details using another matching column
null_position = null_position.copy()
null_position.drop(columns= null_position.iloc[:,32:], inplace= True)
null_position.columns
# Out:
# Index(['User ID', 'Variable', 'Question', 'Topic', 'Answer Label',
#        'Answer Value', 'Age', 'CAP', 'City', 'Num. of Citizens',
#        'Highest Education', 'Survey filling date and time',
#        'Seconds to Answer', 'Sex', 'User Social Weight', 'idRispondente',
#        'Pet Friends', 'Num. of Children (0-14 years)', 'Season', 'Month',
#        'Time Slot', 'birth_year', 'Survey filling date', 'Survey filling hour',
#        'Weekday', 'Mood relationship', 'General Mood', 'Year', 'Generation',
#        'Generation Description', 'Events', 'Event month'],
#       dtype='object')

# %%
# merge null_position the geographical dataframe 
null_position = pd.merge(null_position, geo_details, how='left', left_on='City', right_on='sigla_provincia')
null_position.drop_duplicates(subset=['User ID', 'Question', 'Topic', 'Answer Label'], keep='first', inplace=True, ignore_index=True)

# %%
print(null_position.shape)
pd.Series(null_position.columns)
# Out:
# (19276, 43)
# 0                           User ID
# 1                          Variable
# 2                          Question
# 3                             Topic
# 4                      Answer Label
# 5                      Answer Value
# 6                               Age
# 7                               CAP
# 8                              City
# 9                  Num. of Citizens
# 10                Highest Education
# 11     Survey filling date and time
# 12                Seconds to Answer
# 13                              Sex
# 14               User Social Weight
# 15                    idRispondente
# 16                      Pet Friends
# 17    Num. of Children (0-14 years)
# 18                           Season
# 19                            Month
# 20                        Time Slot
# 21                       birth_year
# 22              Survey filling date
# 23              Survey filling hour
# 24                          Weekday
# 25                Mood relationship
# 26                     General Mood
# 27                             Year
# 28                       Generation
# 29           Generation Description
# 30                           Events
# 31                      Event month
# 32                     Municipality
# 33                         City CAP
# 34                  sigla_provincia
# 35                        City Name
# 36                           Region
# 37                      Region Type
# 38                         Latitude
# 39                        Longitude
# 40                 Altitude Profile
# 41                     Geo Position
# 42               Urbanization Level
# dtype: object

# %%
# create new dataframe 'not_null_position' filtering not null values from the first merge of the main dataframe with the geographical dataframe
not_null_position = survey[survey['Geo Position'].isnull() == False]
print(not_null_position.shape)
pd.Series(not_null_position.columns)
# Out:
# (622204, 43)
# 0                           User ID
# 1                          Variable
# 2                          Question
# 3                             Topic
# 4                      Answer Label
# 5                      Answer Value
# 6                               Age
# 7                               CAP
# 8                              City
# 9                  Num. of Citizens
# 10                Highest Education
# 11     Survey filling date and time
# 12                Seconds to Answer
# 13                              Sex
# 14               User Social Weight
# 15                    idRispondente
# 16                      Pet Friends
# 17    Num. of Children (0-14 years)
# 18                           Season
# 19                            Month
# 20                        Time Slot
# 21                       birth_year
# 22              Survey filling date
# 23              Survey filling hour
# 24                          Weekday
# 25                Mood relationship
# 26                     General Mood
# 27                             Year
# 28                       Generation
# 29           Generation Description
# 30                           Events
# 31                      Event month
# 32                     Municipality
# 33                         City CAP
# 34                  sigla_provincia
# 35                        City Name
# 36                           Region
# 37                      Region Type
# 38                         Latitude
# 39                        Longitude
# 40                 Altitude Profile
# 41                     Geo Position
# 42               Urbanization Level
# dtype: object

# %%
# concat the dataframes 'null_position' and 'not_null_position'. Null values have decreased. Final dataframe is the result
survey_final = pd.concat([not_null_position, null_position], ignore_index=True)
print(survey_final.shape)
survey_final.isnull().sum()
# Out:
# (641480, 43)
# User ID                              0
# Variable                             0
# Question                             0
# Topic                            16240
# Answer Label                         0
# Answer Value                         0
# Age                                  0
# CAP                                  0
# City                             36814
# Num. of Citizens                  4582
# Highest Education                    0
# Survey filling date and time         0
# Seconds to Answer                 6873
# Sex                                  0
# User Social Weight                   0
# idRispondente                    49928
# Pet Friends                      49928
# Num. of Children (0-14 years)    49928
# Season                               0
# Month                                0
# Time Slot                            0
# birth_year                           0
# Survey filling date                  0
# Survey filling hour                  0
# Weekday                              0
# Mood relationship                    0
# General Mood                         0
# Year                                 0
# Generation                           0
# Generation Description               0
# Events                               0
# Event month                          0
# Municipality                      1264
# City CAP                          1264
# sigla_provincia                  37130
# City Name                         1264
# Region                            1264
# Region Type                       1264
# Latitude                          1264
# Longitude                         1264
# Altitude Profile                  1264
# Geo Position                      1264
# Urbanization Level                1264
# dtype: int64

# %%
survey_final.columns
# Out:
# Index(['User ID', 'Variable', 'Question', 'Topic', 'Answer Label',
#        'Answer Value', 'Age', 'CAP', 'City', 'Num. of Citizens',
#        'Highest Education', 'Survey filling date and time',
#        'Seconds to Answer', 'Sex', 'User Social Weight', 'idRispondente',
#        'Pet Friends', 'Num. of Children (0-14 years)', 'Season', 'Month',
#        'Time Slot', 'birth_year', 'Survey filling date', 'Survey filling hour',
#        'Weekday', 'Mood relationship', 'General Mood', 'Year', 'Generation',
#        'Generation Description', 'Events', 'Event month', 'Municipality',
#        'City CAP', 'sigla_provincia', 'City Name', 'Region', 'Region Type',
#        'Latitude', 'Longitude', 'Altitude Profile', 'Geo Position',
#        'Urbanization Level'],
#       dtype='object')

# %%
# drop irrelevant columns from final dataframe
survey_final.drop(columns=['CAP', 'City', 'Num. of Citizens', 'Survey filling date and time', 
                             'idRispondente', 'Month', 'birth_year', 'City CAP', 'sigla_provincia'], inplace=True)

# %%
# save final dataframe to csv
survey_final.to_csv(r'data_clean/04_df_analysis.csv', index=False)
